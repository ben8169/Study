# %% [markdown]
# ## Data Load
#
# - MNIST data: Handwritten digit image dataset
#     - Classifies the digits in the images into 10 classes
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - Upload mnist_train.csv, mnist_test.csv, my_mlp.py files

# %%
import numpy as np
import pandas as pd

# %%
# !pwd
# Out:
# 'pwd' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
train = pd.read_csv('mnist_train.csv', header=None)
X_train = np.array(train.iloc[:, 1:].values.tolist())
y_train = np.array(train[0].values.tolist())

# %%
test = pd.read_csv('mnist_test.csv', header=None)
X_test = np.array(test.iloc[:, 1:].values.tolist())
y_test = np.array(test[0].values.tolist())

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (60000, 784) (10000, 784) (60000,) (10000,)

# %% [markdown]
# ## MLP from Scratch
#
# - Do not change the configured learning rate, batch size, number of neurons, epochs, and layers!

# %%
from sklearn import metrics
from my_mlp-1 import *
import time

mlp = my_MLP()

start = time.time()
mlp.fit(X_train, y_train)

taken = time.time() - start
print(taken, '\n')

y_pred = mlp.predict(X_test)

# print(metrics.classification_report(y_test, y_pred))
# Out:
# 16.481958150863647

# %%
np.array(mlp.hidden_layers[2]).shape
# Out:
# (10000, 10)

# %%
np.array(mlp.weights,dtype=object).shape
# Out:
# (2,)

# %%
np.array(mlp.weights[0],dtype=object).shape
# Out:
# (784, 32)

# %%
np.array(mlp.weights[1]).shape
# Out:
# (32, 10)

# %%
len(mlp.weights)
# Out:
# 2

# %%
l1 = np.random.random((7500,784))
l2 = np.random.random((784,32))
# Out:
# array([ True])

# %%
print(len(mlp.hidden_layers))
print(np.array(mlp.hidden_layers[0],dtype=object).shape)
print(np.array(mlp.hidden_layers[1],dtype=object).shape)
print(np.array(mlp.hidden_layers[2],dtype=object).shape)
# Out:
# 3
# (8, 784)
# (8, 32)
# (8, 10)

# %%
y_pred = mlp.predict(X_test)

# %%
print(len(mlp.hidden_layers))
print(np.array(mlp.hidden_layers[0],dtype=object).shape)
print(np.array(mlp.hidden_layers[1],dtype=object).shape)
print(np.array(mlp.hidden_layers[2],dtype=object).shape)
# Out:
# 3
# (10000, 784)
# (10000, 32)
# (10000, 10)
