# %% [markdown]
# pandas

# %%
import pandas as pd
import numpy as np

# %%
# df = pd.read_csv('comit.csv')
# df

# %%
df = pd.read_excel('comit.xlsx')
df
# Out:
#                       타임스탬프   이름          학번  \
# 0   2024-03-17 21:10:56.261  김재순  2019312463
# 1   2024-03-17 21:10:57.496  서지우  2022316050
# 2   2024-03-17 21:11:02.333  이동률  2023312873
# 3   2024-03-17 21:11:02.940  성민규  2022315944
# 4   2024-03-17 21:11:09.308  한수빈  2021310952
# ..                      ...  ...         ...
# 173 2024-03-18 22:51:43.015   하륜  2024311307
# 174 2024-03-18 22:52:46.406  유재혁  2024310689
# 175 2024-03-18 23:12:02.674  곽정호  2021314650
# 176 2024-03-18 23:12:30.666  엄정우  2022314611
# 177 2024-03-19 00:04:05.532  김유찬  2023311686
#
#                                            지원하는 스터디  \
# 0                    알고리즘(율전 / 박상혁 / 월 20:00-21:30)
# 1                  C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 2                                  웹 개발 초급(명륜 / 공통)
# 3    Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)
# 4                                  웹 개발 초급(율전 / 공통)
# ..                                              ...
# ...

# %%
df.columns
# Out:
# Index(['타임스탬프', '이름', '학번', '지원하는 스터디', '지원 동기'], dtype='object')

# %%
df.columns = ['Time','Name','S_ID','Desired_Study','Motive']
df
# Out:
#                        Time Name        S_ID  \
# 0   2024-03-17 21:10:56.261  김재순  2019312463
# 1   2024-03-17 21:10:57.496  서지우  2022316050
# 2   2024-03-17 21:11:02.333  이동률  2023312873
# 3   2024-03-17 21:11:02.940  성민규  2022315944
# 4   2024-03-17 21:11:09.308  한수빈  2021310952
# ..                      ...  ...         ...
# 173 2024-03-18 22:51:43.015   하륜  2024311307
# 174 2024-03-18 22:52:46.406  유재혁  2024310689
# 175 2024-03-18 23:12:02.674  곽정호  2021314650
# 176 2024-03-18 23:12:30.666  엄정우  2022314611
# 177 2024-03-19 00:04:05.532  김유찬  2023311686
#
#                                       Desired_Study  \
# 0                    알고리즘(율전 / 박상혁 / 월 20:00-21:30)
# 1                  C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 2                                  웹 개발 초급(명륜 / 공통)
# 3    Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)
# 4                                  웹 개발 초급(율전 / 공통)
# ..                                              ...
# ...

# %%
df.describe()
# Out:
#                                 Time          S_ID
# count                            178  1.780000e+02
# mean   2024-03-18 04:35:46.764843008  1.976941e+09
# min       2024-03-17 21:10:56.261000  2.300000e+01
# 25%    2024-03-17 21:15:01.981250048  2.021312e+09
# 50%    2024-03-17 21:55:18.950500096  2.022316e+09
# 75%    2024-03-18 13:54:04.833750016  2.024311e+09
# max       2024-03-19 00:04:05.532000  2.024315e+09
# std                              NaN  3.005933e+08

# %%
df.sort_values(by='Time')
# Out:
#                        Time Name        S_ID  \
# 0   2024-03-17 21:10:56.261  김재순  2019312463
# 1   2024-03-17 21:10:57.496  서지우  2022316050
# 2   2024-03-17 21:11:02.333  이동률  2023312873
# 3   2024-03-17 21:11:02.940  성민규  2022315944
# 4   2024-03-17 21:11:09.308  한수빈  2021310952
# ..                      ...  ...         ...
# 173 2024-03-18 22:51:43.015   하륜  2024311307
# 174 2024-03-18 22:52:46.406  유재혁  2024310689
# 175 2024-03-18 23:12:02.674  곽정호  2021314650
# 176 2024-03-18 23:12:30.666  엄정우  2022314611
# 177 2024-03-19 00:04:05.532  김유찬  2023311686
#
#                                       Desired_Study  \
# 0                    알고리즘(율전 / 박상혁 / 월 20:00-21:30)
# 1                  C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 2                                  웹 개발 초급(명륜 / 공통)
# 3    Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)
# 4                                  웹 개발 초급(율전 / 공통)
# ..                                              ...
# ...

# %%
df.loc[[0,3,5],['Time','Name']]
df.loc[:,'Name']
df.loc[:,['Name','S_ID']]
df.loc[100,'Name']
df.loc[:,list(df.columns)[2:]]
# Out:
#            S_ID                                   Desired_Study  \
# 0    2019312463                  알고리즘(율전 / 박상혁 / 월 20:00-21:30)
# 1    2022316050                C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 2    2023312873                                웹 개발 초급(명륜 / 공통)
# 3    2022315944  Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)
# 4    2021310952                                웹 개발 초급(율전 / 공통)
# ..          ...                                             ...
# 173  2024311307                                웹 개발 초급(율전 / 공통)
# 174  2024310689                                웹 개발 초급(율전 / 공통)
# 175  2021314650                          Python 데이터 분석(율전 / 공통)
# 176  2022314611                          Python 데이터 분석(율전 / 공통)
# 177  2023311686                                웹 개발 초급(율전 / 공통)
#
#                                                 Motive
# 0    이번에 복전을 하면서 소프트웨어학과 수업을 처음 듣게되어 도움을 받고자 신청하게 되...
# 1                                         C언어를 배우고싶습니다
# ...

# %%
df.to_numpy()
# Out:
# array([[Timestamp('2024-03-17 21:10:56.261000'), '김재순', 2019312463,
#         '알고리즘(율전 / 박상혁 / 월 20:00-21:30)',
#         '이번에 복전을 하면서 소프트웨어학과 수업을 처음 듣게되어 도움을 받고자 신청하게 되었습니다'],
#        [Timestamp('2024-03-17 21:10:57.496000'), '서지우', 2022316050,
#         'C 언어 초급(명륜 / 김남준 / 수 13:30-15:00', 'C언어를 배우고싶습니다'],
#        [Timestamp('2024-03-17 21:11:02.333000'), '이동률', 2023312873,
#         '웹 개발 초급(명륜 / 공통)', '웹을 배워 나만의 웹을 구성하고 싶습니당'],
#        [Timestamp('2024-03-17 21:11:02.940000'), '성민규', 2022315944,
#         'Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)',
#         '자바 안드로이드 앱개발 경험있고 코틀린으로도 개발하고싶습니다.'],
#        [Timestamp('2024-03-17 21:11:09.308000'), '한수빈', 2021310952,
#         '웹 개발 초급(율전 / 공통)', '웹 개발 한번 해보고싶습니다.'],
#        [Timestamp('2024-03-17 21:11:14.031000'), '강현도', 2022311011,
#         'Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)',
#         '모바일 개발 수업을 듣게 됐는데 노베이스라 도움을 얻기 위해서 입니다.'],
#        [Timestamp('2024-03-17 21:11:21.523000'), '김민채', 2022310160,
# ...

# %%
df.iloc[2]
df.iloc[2:5, 0:2]
df.iloc[[2,5],0:2]
# Out:
#                      Time Name
# 2 2024-03-17 21:11:02.333  이동률
# 5 2024-03-17 21:11:14.031  강현도

# %%
df.Name
df['Name']
# Out:
# 0      김재순
# 1      서지우
# 2      이동률
# 3      성민규
# 4      한수빈
#       ...
# 173     하륜
# 174    유재혁
# 175    곽정호
# 176    엄정우
# 177    김유찬
# Name: Name, Length: 178, dtype: object

# %%
# df['S_ID'].str.startswith('2022')
# type(df['S_ID'][0])
df['S_ID'] = df['S_ID'].astype(str)
df['S_ID'].str.startswith('2022')
df_2022 = df[df['S_ID'].str.startswith('2022')]

df_2022[df_2022['Desired_Study'].str.contains('명륜',regex=True)]
# df_2022[df_2022['Desired_Study'].isin(['C 언어 초급(명륜 / 김남준 / 수 13:30-15:00'])]
# Out:
#                        Time Name        S_ID  \
# 1   2024-03-17 21:10:57.496  서지우  2022316050
# 24  2024-03-17 21:12:33.409  전수빈  2022312440
# 34  2024-03-17 21:13:42.630  서지우  2022316050
# 118 2024-03-18 09:18:47.986  최태림  2022315947
# 119 2024-03-18 09:26:14.392  배서현  2022315923
#
#                         Desired_Study  \
# 1    C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 24                   C 언어 초급(명륜 / 공통)
# 34                   C 언어 초급(명륜 / 공통)
# 118                  C 언어 초급(명륜 / 공통)
# 119                  C 언어 초급(명륜 / 공통)
#
#                                                 Motive
# 1                                         C언어를 배우고싶습니다
# 24   스터디원과 함께 C언어를 배우면서 C언어 능력 향상을 목표로 하고 싶습니다. 스터디...
# 34   수요일 C언어 스터디가 모집마감되었다구 하여 ㅠㅠ 혹시 몰라 다른 스터디로 지원합니...
# 118  프로그래밍의 가장 기본 언어인 C언어를 기초부터 탄탄히 공부하고 싶어요. 사실 몇 ...
# 119              c언어를 많이 까먹어서 이번기회에 처음부터 다시 배워보고 싶습니다.

# %%
row_num=df.shape[0]
df['PS'] = [None]*row_num
df['Note'] = [None]*row_num
df
# Out:
#                        Time Name        S_ID  \
# 0   2024-03-17 21:10:56.261  김재순  2019312463
# 1   2024-03-17 21:10:57.496  서지우  2022316050
# 2   2024-03-17 21:11:02.333  이동률  2023312873
# 3   2024-03-17 21:11:02.940  성민규  2022315944
# 4   2024-03-17 21:11:09.308  한수빈  2021310952
# ..                      ...  ...         ...
# 173 2024-03-18 22:51:43.015   하륜  2024311307
# 174 2024-03-18 22:52:46.406  유재혁  2024310689
# 175 2024-03-18 23:12:02.674  곽정호  2021314650
# 176 2024-03-18 23:12:30.666  엄정우  2022314611
# 177 2024-03-19 00:04:05.532  김유찬  2023311686
#
#                                       Desired_Study  \
# 0                    알고리즘(율전 / 박상혁 / 월 20:00-21:30)
# 1                  C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 2                                  웹 개발 초급(명륜 / 공통)
# 3    Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)
# 4                                  웹 개발 초급(율전 / 공통)
# ..                                              ...
# ...

# %%
df = df.drop(columns=['PS'])
df
# Out:
#                        Time Name        S_ID  \
# 0   2024-03-17 21:10:56.261  김재순  2019312463
# 1   2024-03-17 21:10:57.496  서지우  2022316050
# 2   2024-03-17 21:11:02.333  이동률  2023312873
# 3   2024-03-17 21:11:02.940  성민규  2022315944
# 4   2024-03-17 21:11:09.308  한수빈  2021310952
# ..                      ...  ...         ...
# 173 2024-03-18 22:51:43.015   하륜  2024311307
# 174 2024-03-18 22:52:46.406  유재혁  2024310689
# 175 2024-03-18 23:12:02.674  곽정호  2021314650
# 176 2024-03-18 23:12:30.666  엄정우  2022314611
# 177 2024-03-19 00:04:05.532  김유찬  2023311686
#
#                                       Desired_Study  \
# 0                    알고리즘(율전 / 박상혁 / 월 20:00-21:30)
# 1                  C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 2                                  웹 개발 초급(명륜 / 공통)
# 3    Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)
# 4                                  웹 개발 초급(율전 / 공통)
# ..                                              ...
# ...

# %%
df.isna()
df.isna().value_counts()
# df.dropna()
df = df.fillna('comit')
df
# Out:
#                        Time Name        S_ID  \
# 0   2024-03-17 21:10:56.261  김재순  2019312463
# 1   2024-03-17 21:10:57.496  서지우  2022316050
# 2   2024-03-17 21:11:02.333  이동률  2023312873
# 3   2024-03-17 21:11:02.940  성민규  2022315944
# 4   2024-03-17 21:11:09.308  한수빈  2021310952
# ..                      ...  ...         ...
# 173 2024-03-18 22:51:43.015   하륜  2024311307
# 174 2024-03-18 22:52:46.406  유재혁  2024310689
# 175 2024-03-18 23:12:02.674  곽정호  2021314650
# 176 2024-03-18 23:12:30.666  엄정우  2022314611
# 177 2024-03-19 00:04:05.532  김유찬  2023311686
#
#                                       Desired_Study  \
# 0                    알고리즘(율전 / 박상혁 / 월 20:00-21:30)
# 1                  C 언어 초급(명륜 / 김남준 / 수 13:30-15:00
# 2                                  웹 개발 초급(명륜 / 공통)
# 3    Kotlin & Android app(율전 / 정정환 / 화 16:00-17:30)
# 4                                  웹 개발 초급(율전 / 공통)
# ..                                              ...
# ...

# %% [markdown]
# numpy

# %%
a = np.array([[1, 2, 3], [4, 5, 6]]) 
[a>2]
a[a>2].reshape(-1,2)
# Out:
# array([[3, 4],
#        [5, 6]])

# %%
b = np.full((5,5),7)
b
# Out:
# array([[7, 7, 7, 7, 7],
#        [7, 7, 7, 7, 7],
#        [7, 7, 7, 7, 7],
#        [7, 7, 7, 7, 7],
#        [7, 7, 7, 7, 7]])

# %%
c = np.random.random((4,4))
#c =  np.random.randint(0, 10, 10)
c = np.array(c, dtype=np.int32)
c
# Out:
# array([3, 0])

# %%
np.random.seed(123)
d = np.random.randint(0, 10, 10).reshape(-1,2)
print(d)
np.sum(d, axis=0),np.sum(d, axis=1)
# Out:
# [[2 2]
#  [6 1]
#  [3 9]
#  [6 1]
#  [0 1]]
# (array([17, 14]), array([ 4,  7, 12,  7,  1]))

# %%
df_np = np.arange(1,13).reshape(-1,3)
df = pd.DataFrame(df_np, columns=['apple','banana','carrot'])
df_filtered = df[(df['apple']>=4) & (df['carrot']<12)]
df_filtered
# Out:
#    apple  banana  carrot
# 1      4       5       6
# 2      7       8       9

# %% [markdown]
# 자율학습
