# %%
import pandas as pd
import numpy as np
from SVM import *

# %%
train_raw = pd.read_csv('preprocessed_train.csv')
train = train_raw.iloc[:,1:]
train
# Out:
#         Altitude  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  \
# 0    2235.355303   7.17    6.08        6.17     7.25  7.33     7.33
# 1    1775.097500   7.33    7.33        7.33     7.58  7.25     8.08
# 2    4000.000000   7.50    7.42        7.42     7.75  7.50     7.50
# 3    1000.000000   7.67    7.67        7.67     7.50  7.42     7.50
# 4    2235.355303   7.50    7.42        7.42     7.42  7.67     7.42
# ..           ...    ...     ...         ...      ...   ...      ...
# 580  1800.000000   7.83    7.75        7.83     7.58  7.67     7.75
# 581  1300.000000   7.83    7.83        7.58     7.92  7.42     7.50
# 582  1200.000000   7.50    7.67        7.50     7.50  7.58     7.58
# 583  1800.000000   7.58    7.67        7.42     7.17  7.17     7.75
# 584  1775.097500   7.67    7.67        7.50     7.50  7.67     7.67
#
#      Uniformity  Clean.Cup  Sweetness  ...  Variety_Yellow Bourbon  \
# 0          10.0       10.0       10.0  ...                   False
# ...

# %%
remaining_cols = train.columns.drop('Country.of.Origin')
X = train[remaining_cols]
Y = train['Country.of.Origin']
X = X.fillna(0)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)
X_train.shape, Y_train.shape
# Out:
# ((468, 38), (468,))

# %%
model = MulticlassSVM()
X_train_np = X_train.to_numpy().astype('float64')
Y_train_np = Y_train.astype('float64')
X_test_np = X_test.to_numpy().astype('float64')
Y_test_np = Y_test.to_numpy().astype('float64')

# %%
from sklearn.model_selection import train_test_split

# 하이퍼파라미터 후보 값들
n_iters_candidates = [5000,10000,15000,20000,30000,40000]
lr_candidates = [0.0001, 0.001, 0.01, 0.1]
lambda_param_candidates = [0.001, 0.01, 0.1, 1, 10]

best_accuracy = 0
best_params = {}

# 데이터 분리

for n_iters in n_iters_candidates:
    for lr in lr_candidates:
        for lambda_param in lambda_param_candidates:
            # MulticlassSVM 객체 생성
            model = MulticlassSVM(n_iters=n_iters, lr=lr, lambda_param=lambda_param)
            
            # 모델 학습
            model.fit(X_train_np, Y_train_np)
            
            # 평가 데이터셋으로 예측 및 정확도 계산
            y_pred = model.predict(X_test_np)
            accuracy = model.get_accuracy(Y_test_np, y_pred)
            
            # 최고 정확도 모델 기록
            if accuracy > best_accuracy:
                best_accuracy = accuracy
                best_params = {'n_iters': n_iters, 'lr': lr, 'lambda_param': lambda_param}

print(f"Best Accuracy: {best_accuracy:.2f}")
print(f"Best Parameters: {best_params}")

# %%
Y_pred = model.predict(X_test)
accuracy = model.get_accuracy(Y_test, Y_pred)
print(f"Accuracy: {accuracy:.6f}%")
# Out:
# Accuracy: 17.094017%

# %%
list(zip(Y_test, Y_pred))
# Out:
# [(3, 0),
#  (3, 0),
#  (2, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (1, 0),
#  (2, 0),
#  (1, 0),
#  (1, 0),
#  (2, 0),
#  (2, 3),
#  (0, 0),
#  (1, 0),
#  (1, 3),
#  (1, 0),
#  (3, 0),
#  (3, 3),
#  (0, 0),
#  (0, 0),
#  (2, 0),
#  (2, 0),
#  (0, 0),
#  (3, 0),
#  (0, 0),
#  (1, 0),
#  (2, 0),
#  (2, 0),
#  (1, 0),
#  (2, 0),
#  (2, 0),
#  (3, 0),
#  (1, 0),
#  (2, 0),
#  (1, 0),
#  (1, 0),
#  (3, 3),
#  (0, 0),
#  (0, 0),
#  (3, 0),
#  (2, 0),
#  (2, 0),
#  (2, 0),
#  (3, 0),
#  (2, 0),
#  (2, 0),
#  (2, 0),
#  (0, 0),
#  (2, 0),
#  (2, 0),
#  (3, 3),
#  (1, 0),
#  (3, 0),
#  (2, 0),
#  (2, 0),
#  (2, 0),
#  (3, 0),
#  (3, 0),
#  (3, 0),
#  (2, 0),
#  (2, 0),
#  (3, 0),
#  (2, 0),
#  (2, 0),
#  (3, 0),
#  (3, 0),
#  (0, 0),
#  (2, 0),
#  (2, 0),
#  (3, 0),
#  (1, 0),
#  (0, 0),
#  (0, 0),
#  (3, 0),
#  (2, 0),
#  (3, 0),
#  (1, 0),
#  (2, 0),
#  (2, 0),
#  (3, 0),
#  (2, 0),
#  (1, 0),
#  (3, 0),
#  (3, 0),
#  (2, 0),
#  (3, 0),
#  (1, 0),
#  (1, 0),
# ...

# %%
correct, wrong = 0, 0
for i, j in list(zip(Y_test, Y_pred)):
    if i == j : correct+=1
    else: wrong +=1
correct, wrong
# Out:
# (20, 97)

# %%
test_raw = pd.read_csv('preprocessed_test.csv')
test = test_raw.iloc[:,1:]
test
# Out:
#         Altitude  Aroma  Flavor  Aftertaste  Acidity  Body  Balance  \
# 0    1250.000000   7.33    7.08        6.92     7.42  7.25     7.08
# 1    1600.000000   7.75    7.83        7.58     8.00  7.92     7.75
# 2    1775.097500   7.83    7.50        7.50     7.42  7.50     7.50
# 3    1020.000000   7.42    7.33        7.33     7.50  7.50     7.33
# 4     975.000000   7.33    7.17        7.00     6.75  7.08     7.00
# ..           ...    ...     ...         ...      ...   ...      ...
# 142  1775.097500   7.83    7.67        7.75     7.58  7.92     7.75
# 143  1447.067619   7.58    7.58        7.58     7.67  7.75     7.67
# 144  1800.000000   7.75    7.58        7.67     7.25  7.58     7.42
# 145  1100.000000   7.83    7.75        7.50     7.75  7.50     7.58
# 146  1750.000000   7.58    7.67        7.75     7.67  7.67     7.67
#
#      Uniformity  Clean.Cup  Sweetness  ...  Variety_Yellow Bourbon  \
# 0          10.0       10.0       10.0  ...                   False
# ...

# %%
X_train.columns
len(X_train.columns)
# Out:
# 38

# %%
test.columns
len(test.columns)
# Out:
# 34

# %%
from sklearn.svm import SVC
import joblib


joblib.dump(model, 'svm_model.pkl')
# Out:
# ['svm_model.pkl']

# %%
# 모델 학습 시 사용된 열 이름 확인
feature_names = loaded_model.feature_names_in_

# 예측 데이터셋에 없는 열 추가 (0으로 채움)
test = test.reindex(columns=feature_names, fill_value=0)

# 예측 수행
y_pred = loaded_model.predict(test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # 모델 학습 시 사용된 열 이름 확인
# ----> 2 feature_names = loaded_model.feature_names_in_
#       4 # 예측 데이터셋에 없는 열 추가 (0으로 채움)
#       5 test = test.reindex(columns=feature_names, fill_value=0)
#
# NameError: name 'loaded_model' is not defined

# %%
y_pred
# Out:
# array([3, 2, 1, 0, 3, 2, 1, 3, 0, 3, 2, 3, 1, 3, 1, 2, 1, 1, 2, 3, 2, 3,
#        2, 1, 1, 3, 1, 3, 0, 3, 3, 1, 3, 3, 3, 0, 3, 2, 0, 1, 1, 3, 1, 2,
#        0, 0, 1, 0, 3, 0, 0, 0, 3, 1, 1, 1, 1, 0, 2, 3, 0, 2, 1, 2, 0, 0,
#        3, 1, 0, 3, 2, 2, 0, 1, 0, 1, 2, 3, 3, 3, 2, 1, 3, 3, 1, 0, 1, 3,
#        1, 2, 3, 3, 3, 3, 3, 2, 0, 0, 1, 1, 2, 1, 3, 0, 1, 0, 1, 3, 3, 0,
#        1, 2, 1, 0, 1, 2, 1, 1, 1, 3, 0, 1, 3, 1, 3, 2, 1, 3, 1, 3, 3, 1,
#        3, 3, 1, 0, 3, 0, 1, 3, 1, 1, 1, 1, 1, 0, 1], dtype=int64)

# %%
import joblib

# 모델 불러오기
loaded_model = joblib.load('svm_model.pkl')

# 테스트 데이터셋에 대한 예측
y_pred = loaded_model.predict(test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 7
#       4 loaded_model = joblib.load('svm_model.pkl')
#       6 # 테스트 데이터셋에 대한 예측
# ----> 7 y_pred = loaded_model.predict(test)
#
# File c:\Users\ben81\anaconda3\Lib\site-packages\sklearn\svm\_base.py:820, in BaseSVC.predict(self, X)
#     818     y = np.argmax(self.decision_function(X), axis=1)
#     819 else:
# --> 820     y = super().predict(X)
#     821 return self.classes_.take(np.asarray(y, dtype=np.intp))
#
# File c:\Users\ben81\anaconda3\Lib\site-packages\sklearn\svm\_base.py:433, in BaseLibSVM.predict(self, X)
#     417 def predict(self, X):
#     418     """Perform regression on samples in X.
#     419
#     420     For an one-class model, +1 (inlier) or -1 (outlier) is returned.
#    (...)
#     431         The predicted values.
#     432     """
# --> 433     X = self._validate_for_predict(X)
# ...

# %%
df = pd.read_csv('submission.csv')
df
# Out:
#       id  Country.of.Origin
# 0      0                  0
# 1      1                  1
# 2      2                  2
# 3      3                  3
# 4      4                  0
# ..   ...                ...
# 142  142                  2
# 143  143                  3
# 144  144                  0
# 145  145                  1
# 146  146                  2
#
# [147 rows x 2 columns]

# %%
df['Country.of.Origin'] = y_pred
df
# Out:
#       id  Country.of.Origin
# 0      0                  3
# 1      1                  2
# 2      2                  1
# 3      3                  0
# 4      4                  3
# ..   ...                ...
# 142  142                  1
# 143  143                  1
# 144  144                  1
# 145  145                  0
# 146  146                  1
#
# [147 rows x 2 columns]

# %%
df.to_csv('submission.csv',index=False)
