# %%
import pandas as pd
import numpy as np

# %%
train_raw = pd.read_csv('train.csv')
test_raw  = pd.read_csv('test.csv')

train_raw
# Out:
#      Unnamed: 0  Species              Farm.Name  Lot.Number  \
# 0             0  Arabica     conquista / morito         NaN
# 1             1  Arabica                    NaN         NaN
# 2             2  Arabica           la esmeralda  11/23/0634
# 3             3  Arabica  fazenda santo antonio         NaN
# 4             4  Arabica                    NaN         NaN
# ..          ...      ...                    ...         ...
# 580         580  Arabica                    NaN         NaN
# 581         581  Arabica                cafetal         101
# 582         582  Arabica              las lomas         NaN
# 583         583  Arabica                    NaN         NaN
# 584         584  Arabica                    NaN         NaN
#
#                  Altitude  Number.of.Bags Bag.Weight  Harvest.Year  \
# 0                     NaN             250       1 kg          2012
# 1    de 1.600 a 1.950 msn             275      70 kg  Mayo a Julio
# 2                    4000              25      69 kg          2017
# 3                900-1100             305       2 kg          2014
# 4                     NaN               1      5 lbs          2013
# ..                    ...             ...        ...           ...
# 580                  1800             275       2 kg     2015/2016
# 581                  1300             200      69 kg          2017
# 582                  1200             250       1 kg          2012
# 583             1800 msnm             250      70 kg         4T/10
# 584   de 1600 a 1950 msnm             138      70 kg          2014
#
#              Grading.Date     Variety  ... Sweetness  Cupper.Points  \
# 0      January 13th, 2012     Bourbon  ...      10.0           7.00
# 1         July 29th, 2011     Caturra  ...      10.0           8.17
# 2     September 8th, 2017     Bourbon  ...      10.0           7.50
# 3     February 13th, 2015      Catuai  ...      10.0           7.58
# 4    September 12th, 2014         NaN  ...      10.0           7.25
# ..                    ...         ...  ...       ...            ...
# 580        June 5th, 2015       Other  ...      10.0           7.83
# 581        July 3rd, 2017  Mundo Novo  ...      10.0           7.83
# 582       July 11th, 2012     Bourbon  ...      10.0           7.67
# 583    February 9th, 2011         NaN  ...      10.0           7.42
# 584       April 8th, 2014     Caturra  ...      10.0           8.33
#
#      Total.Cup.Points  Moisture  Category.One.Defects  Quakers  Color  \
# 0               78.33      0.11                     0      0.0  Green
# 1               83.08      0.01                     0      0.0    NaN
# 2               82.58      0.10                     0      1.0  Green
# 3               83.00      0.00                     0      0.0  Green
# 4               82.08      0.11                     1      0.0  Green
# ..                ...       ...                   ...      ...    ...
# 580             84.25      0.12                     0      0.0  Green
# 581             83.92      0.11                     0      0.0  Green
# 582             83.00      0.11                     5      0.0  Green
# 583             82.17      0.08                     0      0.0    NaN
# 584             84.00      0.12                     0      0.0  Green
#
#      Category.Two.Defects            Expiration  Country.of.Origin
# 0                       9    January 12th, 2013                  2
# 1                       0       July 28th, 2012                  1
# 2                       2   September 8th, 2018                  2
# 3                       0   February 13th, 2016                  0
# 4                       0  September 12th, 2015                  1
# ..                    ...                   ...                ...
# 580                     0        June 4th, 2016                  1
# 581                     5        July 3rd, 2018                  3
# 582                     8       July 11th, 2013                  3
# 583                     0    February 9th, 2012                  1
# 584                     3       April 8th, 2015                  1
#
# [585 rows x 29 columns]

# %%
train_raw.isna().sum(), test_raw.isna().sum()
# Out:
# (Unnamed: 0                0
#  Species                   0
#  Farm.Name               166
#  Lot.Number              480
#  Altitude                 67
#  Number.of.Bags            0
#  Bag.Weight                0
#  Harvest.Year             10
#  Grading.Date              0
#  Variety                  61
#  Processing.Method        52
#  Aroma                     0
#  Flavor                    0
#  Aftertaste                0
#  Acidity                   0
#  Body                      0
#  Balance                   0
#  Uniformity                0
#  Clean.Cup                 0
#  Sweetness                 0
#  Cupper.Points             0
#  Total.Cup.Points          0
#  Moisture                  0
#  Category.One.Defects      0
#  Quakers                   1
#  Color                   116
#  Category.Two.Defects      0
#  Expiration                0
#  Country.of.Origin         0
#  dtype: int64,
#  Unnamed: 0                0
#  Species                   0
#  Farm.Name                49
#  Lot.Number              118
#  Altitude                 20
#  Number.of.Bags            0
#  Bag.Weight                0
#  Harvest.Year              2
#  Grading.Date              0
#  Variety                  12
#  Processing.Method        12
#  Aroma                     0
#  Flavor                    0
#  Aftertaste                0
#  Acidity                   0
#  Body                      0
#  Balance                   0
#  Uniformity                0
#  Clean.Cup                 0
#  Sweetness                 0
#  Cupper.Points             0
#  Total.Cup.Points          0
#  Moisture                  0
#  Category.One.Defects      0
#  Quakers                   0
#  Color                    26
#  Category.Two.Defects      0
#  Expiration                0
#  dtype: int64)

# %% [markdown]
# ### Drop Columns

# %%
train_raw.columns
# Out:
# Index(['Unnamed: 0', 'Species', 'Farm.Name', 'Lot.Number', 'Altitude',
#        'Number.of.Bags', 'Bag.Weight', 'Harvest.Year', 'Grading.Date',
#        'Variety', 'Processing.Method', 'Aroma', 'Flavor', 'Aftertaste',
#        'Acidity', 'Body', 'Balance', 'Uniformity', 'Clean.Cup', 'Sweetness',
#        'Cupper.Points', 'Total.Cup.Points', 'Moisture', 'Category.One.Defects',
#        'Quakers', 'Color', 'Category.Two.Defects', 'Expiration',
#        'Country.of.Origin'],
#       dtype='object')

# %%
drop_cols = ['Farm.Name','Lot.Number','Harvest.Year','Species', 'Number.of.Bags','Bag.Weight','Grading.Date','Expiration','Unnamed: 0']    
#'Altitude' , 'Variety','Processing.Method','Color','Quakers'
drop_cols += []     # meaningless

train = train_raw.drop(columns=drop_cols)
test = test_raw.drop(columns=drop_cols)
train['Quakers'].fillna(0)
test['Quakers'].fillna(0)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 142    0
# 143    0
# 144    0
# 145    0
# 146    0
# Name: Quakers, Length: 147, dtype: int64

# %% [markdown]
# ### Preprocessing

# %% [markdown]
# #### Altitude

# %%
import re

altitudes = train_raw['Altitude'].to_numpy()


def preprocess_altitudes(altitudes):
    lst = []
    for altitude in altitudes:
        altitude = str(altitude)
        if altitude == 'nan' : lst.append(0)
        else:
        # Remove chars except 0-9 and -
            cleaned_altitude = re.sub(r'[^0-9\-]+', '', altitude)
            
            # Handle ranges
            if '-' in cleaned_altitude:
                start, end = map(int, cleaned_altitude.split('-'))
                average = (start + end) / 2
                lst.append(average)

            elif len(cleaned_altitude)>=7:
                start, end = int(cleaned_altitude)/10000, int(cleaned_altitude)%10000
                average = (start + end) / 2
                lst.append(average)

            else:
                try:
                    lst.append(int(cleaned_altitude))
                except:
                    lst.append(0)
        
    return lst

preprocessed_altitudes = preprocess_altitudes(altitudes)
print(preprocessed_altitudes)
# Out:
# [0, 1775.0974999999999, 4000, 1000.0, 0, 1750, 4300, 12, 1300, 1750, 1700, 1400, 1750, 774, 442, 905, 890, 4000, 442, 1300, 1775.0974999999999, 1400, 1261, 1100, 1, 1100, 995, 1200, 1600, 1350, 1000, 0, 3280, 1500, 1500, 4540, 0, 1000, 1800, 0, 0, 0, 1550, 1750, 1100, 1450.0, 0, 1775.0974999999999, 1800, 1600, 1, 1775.0974999999999, 1500, 0, 1750, 0, 439, 890, 1200, 1300, 1700, 982, 695, 1450, 1483, 0, 1100, 1170, 1800, 1000, 0, 1750, 700, 1901, 4000, 950, 1000, 5000, 1100, 1200, 1400, 1000, 1800, 4300, 1700, 900, 1700, 950, 1200, 905, 0, 1250, 1750, 1200, 1100, 1100, 0, 1250, 1450, 1650, 1210, 5000, 1600, 1775.0974999999999, 1750.095, 1550, 4000, 1000, 4300, 1550, 1100, 1400, 4000, 1300, 940, 1400, 1350, 1550.0900000000001, 900, 1770, 1400.0, 442, 0, 0, 1250, 4300, 1775.0974999999999, 1300, 1150, 0, 1400, 0, 1800, 1600, 0, 1250, 1400.075, 1750, 940, 1775.0974999999999, 3850.295, 1250, 0, 1500, 442, 4000, 1500, 5000, 1450, 1300, 1800, 3607, 1150, 4000, 0, 1750, 4300, 1250, 2527, 4300, 4000, 1450, 1000, 1700.0, 0, 1600, 1550, 1300, 890, 1400, 0, 4000, 1700, 4500, 1200, 1260, 4451, 1750, 0, 850, 1880, 750, 1100, 1700, 518, 1300, 1500, 0, 4650, 1200, 934, 0, 1800, 1000, 1480, 1100, 1550, 1100, 1050, 5000, 1380, 100, 0, 0, 1750, 1750, 1200, 1264, 442, 925.0, 1250, 1250, 1200, 934, 890, 1750, 1300, 934, 890, 1400, 1775.0974999999999, 1400, 1400, 1050, 1775.0974999999999, 4000, 4650, 1100, 4300, 1400, 1200, 1775.0974999999999, 1500, 4600, 905, 1500, 1550, 1625.0, 1600, 890, 1218, 4350.0, 1750, 1750, 1550, 1100, 1650, 1250, 1550, 900, 4300, 890, 1059, 1550, 1450, 934, 872, 973, 1100, 4300, 4000, 1300, 1100, 1550, 1775.0974999999999, 1550, 1250, 1800, 4000, 1248, 800, 1700.0, 12, 0, 1800, 1038.5, 1300, 1850, 0, 1800, 4300, 1250, 1250, 1400, 1650, 1550, 1400, 1500, 5600.0, 0, 763, 1500, 4350.0, 4300, 1775.0, 894, 1350, 518, 5000, 1200, 1775.0974999999999, 1380, 4300, 1775.0974999999999, 1296, 1250, 1750, 1700, 1300, 1550, 1650, 190164, 4000, 1200, 1400, 1200, 0, 1300, 0, 1500, 1, 4000, 1600, 1400, 1775.0974999999999, 4000, 1050.0, 1450.0, 0, 1450, 1100, 4300, 1100, 940, 0, 0, 1650.0, 4000, 0, 1260, 1775.0974999999999, 900, 1100, 1200, 1700, 1500, 950, 1250, 1500, 0, 4300, 1170, 0, 442, 1200, 1100, 1100, 1400, 1200.0, 1300, 4300, 4300, 5000, 950, 1600, 890, 4300, 1550, 1550, 1130, 1250, 1600.0, 533, 1450, 1550, 0, 1750, 4300, 1900.0, 1100, 1200, 1000, 890, 1000, 1, 0, 1260, 1300, 1625.0, 1500, 1227, 1500, 1700, 1300, 4000, 1700, 4300, 1, 1, 4563, 750, 890, 441, 1200, 1186, 1700.0, 12, 1500, 4300, 1400, 1750, 0, 1650, 1775.0974999999999, 1800, 0, 1775.0974999999999, 532, 1250, 1170, 1089, 1250, 1200, 1450, 1550.0900000000001, 0, 4500, 11000, 1400, 442, 1500, 4300, 940, 1100, 975.0, 1260, 1140, 1600, 1500, 1400, 1100, 0, 1500, 1530, 900, 1600, 4500, 4300, 1100, 0, 1300, 1100, 850, 1480, 1901, 4600, 0, 981, 1642, 1550, 0, 0, 1300, 1250, 175, 1300, 1320, 1250, 0, 4000, 1800, 1300.0700000000002, 1400, 1100, 1000, 1100, 1550.0, 0, 4000, 4300, 1775.0974999999999, 1170, 5600.0, 1100, 1268, 6100, 5750.0, 1300, 1700, 1425.0, 1250, 1100, 125, 1050.0, 1250, 0, 5000, 4000, 1300, 1813, 1200, 0, 0, 4000, 1880, 690, 1901, 0, 1200, 1000, 1550, 0, 5750.0, 4300, 890, 1200, 0, 0, 1300, 950, 3664, 2100, 1550, 1600, 0, 1775.0974999999999, 1600, 442, 0, 1100, 1150, 1000, 5680.0, 1300, 0, 1750, 1750, 1799, 0, 1200, 1250, 1500, 190164, 1799, 1100, 1100, 4300, 1500, 1250, 4300, 4000, 0, 1775.0974999999999, 0, 0, 2136, 5000, 1300, 1550, 1450.0, 1450, 0, 1338, 1700, 1750, 4000, 4000, 442, 1550, 4000, 1260, 1038.5, 1550.0900000000001, 1100, 1000, 518, 1200, 0, 2560, 0, 1800, 1300, 1200, 1800, 1775.0974999999999]

# %%
mean_val = np.mean(preprocessed_altitudes)
preprocessed_altitudes = [val if val != 0 else mean_val for val in preprocessed_altitudes]

train['Altitude'] = preprocessed_altitudes
train
# Out:
#         Altitude     Variety Processing.Method  Aroma  Flavor  Aftertaste  \
# 0    2235.355303     Bourbon      Washed / Wet   7.17    6.08        6.17
# 1    1775.097500     Caturra               NaN   7.33    7.33        7.33
# 2    4000.000000     Bourbon      Washed / Wet   7.50    7.42        7.42
# 3    1000.000000      Catuai     Natural / Dry   7.67    7.67        7.67
# 4    2235.355303         NaN      Washed / Wet   7.50    7.42        7.42
# ..           ...         ...               ...    ...     ...         ...
# 580  1800.000000       Other      Washed / Wet   7.83    7.75        7.83
# 581  1300.000000  Mundo Novo      Washed / Wet   7.83    7.83        7.58
# 582  1200.000000     Bourbon      Washed / Wet   7.50    7.67        7.50
# 583  1800.000000         NaN               NaN   7.58    7.67        7.42
# 584  1775.097500     Caturra      Washed / Wet   7.67    7.67        7.50
#
#      Acidity  Body  Balance  Uniformity  Clean.Cup  Sweetness  Cupper.Points  \
# 0       7.25  7.33     7.33        10.0       10.0       10.0           7.00
# 1       7.58  7.25     8.08        10.0       10.0       10.0           8.17
# 2       7.75  7.50     7.50        10.0       10.0       10.0           7.50
# 3       7.50  7.42     7.50        10.0       10.0       10.0           7.58
# 4       7.42  7.67     7.42        10.0       10.0       10.0           7.25
# ..       ...   ...      ...         ...        ...        ...            ...
# 580     7.58  7.67     7.75        10.0       10.0       10.0           7.83
# 581     7.92  7.42     7.50        10.0       10.0       10.0           7.83
# 582     7.50  7.58     7.58        10.0       10.0       10.0           7.67
# 583     7.17  7.17     7.75        10.0       10.0       10.0           7.42
# 584     7.50  7.67     7.67        10.0       10.0       10.0           8.33
#
#      Total.Cup.Points  Moisture  Category.One.Defects  Quakers  Color  \
# 0               78.33      0.11                     0      0.0  Green
# 1               83.08      0.01                     0      0.0    NaN
# 2               82.58      0.10                     0      1.0  Green
# 3               83.00      0.00                     0      0.0  Green
# 4               82.08      0.11                     1      0.0  Green
# ..                ...       ...                   ...      ...    ...
# 580             84.25      0.12                     0      0.0  Green
# 581             83.92      0.11                     0      0.0  Green
# 582             83.00      0.11                     5      0.0  Green
# 583             82.17      0.08                     0      0.0    NaN
# 584             84.00      0.12                     0      0.0  Green
#
#      Category.Two.Defects  Country.of.Origin
# 0                       9                  2
# 1                       0                  1
# 2                       2                  2
# 3                       0                  0
# 4                       0                  1
# ..                    ...                ...
# 580                     0                  1
# 581                     5                  3
# 582                     8                  3
# 583                     0                  1
# 584                     3                  1
#
# [585 rows x 20 columns]

# %%
import re

altitudes = test_raw['Altitude'].to_numpy()


def preprocess_altitudes(altitudes):
    lst = []
    for altitude in altitudes:
        altitude = str(altitude)
        if altitude == 'nan' : lst.append(0)
        else:
        # Remove chars except 0-9 and -
            cleaned_altitude = re.sub(r'[^0-9\-]+', '', altitude)
            
            # Handle ranges
            if '-' in cleaned_altitude:
                start, end = map(int, cleaned_altitude.split('-'))
                average = (start + end) / 2
                lst.append(average)

            elif len(cleaned_altitude)>=7:
                start, end = int(cleaned_altitude)/10000, int(cleaned_altitude)%10000
                average = (start + end) / 2
                lst.append(average)

            else:
                try:
                    lst.append(int(cleaned_altitude))
                except:
                    lst.append(0)
        
    return lst

preprocessed_altitudes = preprocess_altitudes(altitudes)
print(preprocessed_altitudes)
# Out:
# [1250, 1600, 1775.0974999999999, 1020, 975, 3280, 0, 1100, 800, 1600, 0, 1679, 2136, 1200, 2560, 1700, 442, 442, 4600, 1350, 4300, 1170, 3280, 4550.0, 0, 700, 1565, 1650, 1100, 1700, 1250, 1900.0, 1550, 1450, 1250, 1000, 808, 5600.0, 0, 1800, 0, 1144, 1550, 3702, 1, 0, 1200, 1100, 1150, 1050, 0, 1260, 1650, 1500, 1775.0974999999999, 0, 1000, 1, 4300, 0, 1, 5000, 1600, 4300, 0, 1200, 1650, 1750, 1275.0675, 1022, 1400, 4300, 0, 0, 934, 1450, 1700, 1248, 1300, 1200, 1800, 0, 1500, 1320, 0, 900, 1000, 1296, 1750, 4300, 1200, 1000, 1500, 1500, 1000, 4000, 894, 1, 1775.0974999999999, 1750, 5500, 1775.0974999999999, 1100, 1150, 0, 1100, 1775.0974999999999, 1600.0, 0, 1200, 1880, 4000, 1775.0, 1100, 1900.0, 1500, 0, 1400, 0, 1560, 944, 1625.0925, 1170, 1320, 950, 5000, 1650, 165, 442, 1200, 1250, 1800, 1050, 1280, 1775.0974999999999, 0, 1200, 1, 1775.0974999999999, 1300, 0, 1750, 1775.0974999999999, 0, 1800, 1100, 1750]

# %%
mean_val = np.mean(preprocessed_altitudes)
preprocessed_altitudes = [val if val != 0 else mean_val for val in preprocessed_altitudes]
test['Altitude'] = preprocessed_altitudes
test
# Out:
#         Altitude  Variety          Processing.Method  Aroma  Flavor  \
# 0    1250.000000   Typica               Washed / Wet   7.33    7.08
# 1    1600.000000  Bourbon               Washed / Wet   7.75    7.83
# 2    1775.097500  Caturra               Washed / Wet   7.83    7.50
# 3    1020.000000   Catuai              Natural / Dry   7.42    7.33
# 4     975.000000  Caturra               Washed / Wet   7.33    7.17
# ..           ...      ...                        ...    ...     ...
# 142  1775.097500  Caturra               Washed / Wet   7.83    7.67
# 143  1447.067619      NaN                        NaN   7.58    7.58
# 144  1800.000000  Caturra               Washed / Wet   7.75    7.58
# 145  1100.000000   Catuai  Semi-washed / Semi-pulped   7.83    7.75
# 146  1750.000000  Caturra               Washed / Wet   7.58    7.67
#
#      Aftertaste  Acidity  Body  Balance  Uniformity  Clean.Cup  Sweetness  \
# 0          6.92     7.42  7.25     7.08        10.0       10.0       10.0
# 1          7.58     8.00  7.92     7.75        10.0       10.0       10.0
# 2          7.50     7.42  7.50     7.50        10.0       10.0       10.0
# 3          7.33     7.50  7.50     7.33        10.0       10.0       10.0
# 4          7.00     6.75  7.08     7.00        10.0       10.0       10.0
# ..          ...      ...   ...      ...         ...        ...        ...
# 142        7.75     7.58  7.92     7.75        10.0       10.0       10.0
# 143        7.58     7.67  7.75     7.67        10.0       10.0       10.0
# 144        7.67     7.25  7.58     7.42        10.0       10.0       10.0
# 145        7.50     7.75  7.50     7.58        10.0       10.0       10.0
# 146        7.75     7.67  7.67     7.67        10.0       10.0       10.0
#
#      Cupper.Points  Total.Cup.Points  Moisture  Category.One.Defects  Quakers  \
# 0             7.08             80.17      0.11                     0        0
# 1             7.83             84.67      0.10                     0        0
# 2             7.58             82.83      0.11                     0        0
# 3             7.50             81.92      0.11                     0        0
# 4             7.33             79.67      0.13                     5        0
# ..             ...               ...       ...                   ...      ...
# 142           7.75             84.25      0.12                     4        0
# 143           7.58             83.42      0.10                     1        0
# 144           7.42             82.67      0.11                     0        0
# 145           7.67             83.58      0.12                     0        0
# 146           7.75             83.75      0.00                     0        0
#
#             Color  Category.Two.Defects
# 0           Green                     2
# 1           Green                     1
# 2           Green                     3
# 3           Green                     4
# 4             NaN                     6
# ..            ...                   ...
# 142         Green                     2
# 143           NaN                     3
# 144  Bluish-Green                     3
# 145    Blue-Green                     2
# 146    Blue-Green                     1
#
# [147 rows x 19 columns]

# %% [markdown]
# #### variety

# %%
variety = train['Variety']
variety.fillna('Other',inplace=True)

# %%
variety = test['Variety']
variety.fillna('Other',inplace=True)

# %% [markdown]
# #### Processing.Method

# %%
P_method = train['Processing.Method']
P_method.fillna('Other',inplace=True)

# %%
P_method = test['Processing.Method']
P_method.fillna('Other',inplace=True)

# %% [markdown]
# #### color

# %%
color = train['Color']
color.fillna('Other',inplace=True)

# %%
color = test['Color']
color.fillna('Other',inplace=True)

# %%
train.isna().sum().to_numpy().all(),test.isna().sum().to_numpy().all()
# Out:
# (False, False)

# %%
train.columns
# Out:
# Index(['Altitude', 'Variety', 'Processing.Method', 'Aroma', 'Flavor',
#        'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity', 'Clean.Cup',
#        'Sweetness', 'Cupper.Points', 'Total.Cup.Points', 'Moisture',
#        'Category.One.Defects', 'Quakers', 'Color', 'Category.Two.Defects',
#        'Country.of.Origin'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['Altitude', 'Variety', 'Processing.Method', 'Aroma', 'Flavor',
#        'Aftertaste', 'Acidity', 'Body', 'Balance', 'Uniformity', 'Clean.Cup',
#        'Sweetness', 'Cupper.Points', 'Total.Cup.Points', 'Moisture',
#        'Category.One.Defects', 'Quakers', 'Color', 'Category.Two.Defects'],
#       dtype='object')

# %% [markdown]
# #### One-Hot Encoding

# %%
one_hot_train = pd.get_dummies(train)
one_hot_test = pd.get_dummies(test)

# %%
one_hot_train.corr()['Country.of.Origin']
# Out:
# Altitude                                       0.018615
# Aroma                                         -0.170782
# Flavor                                        -0.261109
# Aftertaste                                    -0.310908
# Acidity                                       -0.114522
# Body                                          -0.290722
# Balance                                       -0.316077
# Uniformity                                    -0.100379
# Clean.Cup                                     -0.039066
# Sweetness                                      0.000975
# Cupper.Points                                 -0.302856
# Total.Cup.Points                              -0.258803
# Moisture                                       0.331794
# Category.One.Defects                           0.132010
# Quakers                                       -0.139952
# Category.Two.Defects                           0.250217
# Country.of.Origin                              1.000000
# Variety_Arusha                                -0.090067
# Variety_Blue Mountain                          0.048190
# Variety_Bourbon                                0.007793
# Variety_Catuai                                -0.125075
# Variety_Caturra                               -0.154826
# Variety_Marigojipe                             0.048190
# Variety_Moka Peaberry                         -0.064424
# Variety_Mundo Novo                            -0.120750
# Variety_Other                                 -0.138362
# Variety_Pacamara                               0.099635
# Variety_Pacas                                  0.041595
# Variety_Typica                                 0.547729
# Variety_Yellow Bourbon                        -0.322016
# Processing.Method_Natural / Dry               -0.407572
# Processing.Method_Other                       -0.153626
# Processing.Method_Pulped natural / honey      -0.158485
# Processing.Method_Semi-washed / Semi-pulped   -0.138699
# Processing.Method_Washed / Wet                 0.525309
# Color_Blue-Green                              -0.131440
# Color_Bluish-Green                            -0.113359
# Color_Green                                    0.016840
# Color_Other                                    0.104682
# Name: Country.of.Origin, dtype: float64

# %%
one_hot_train.to_csv('preprocessed_train.csv')
one_hot_test.to_csv('preprocessed_test.csv')
